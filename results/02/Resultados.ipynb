# %%
import plotly
import pandas
import numpy
import scipy
import plotly.plotly as py
import plotly.graph_objs as go

# Importando os dados
# RRLS = pandas.read_csv("RRLS.csv")
ILS = pandas.read_csv("ILS.csv")
ILS_S = pandas.read_csv("ILS_S.csv")

MAX_FITNESS = {"abba": 43, "aman-aplan": 40, "four": 42, "order": 42, "ranges": 42, "triples": 42,"words": 40}
FITNESS_LINE = go.Scatter(name="Max Fitness", x=list(MAX_FITNESS.keys()), y=list(MAX_FITNESS.values()), mode='lines', marker=go.Marker(color='rgb(255, 77, 77)'))

# %%
# Boxplot comparando 'melhor fitness'
data = [
    # go.Box(name="RRLS", x=RRLS.Nome, y=RRLS.Melhor_fitness),
    go.Box(name="ILS", x=ILS.Nome, y=ILS.Melhor_fitness),
    go.Box(name="ILS_S", x=ILS_S.Nome, y=ILS_S.Melhor_fitness),
    FITNESS_LINE,
]

layout = go.Layout(title="Melhor fitness",
                xaxis=dict(title='Instâncias'),
                yaxis=dict(title='fitness'),
                boxmode='group')
fig = go.Figure(data=data, layout=layout)

py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~andrefarzat/339.embed" height="525px" width="100%"></iframe>

# %%
ILS
# Out:
#       Nome  Depth   i        Melhor_solucao  Melhor_fitness  \
# 0     abba      5   1                   NaN               0
# 1     abba      5   2                   NaN               0
# 2     abba      5   3                   NaN               0
# 3     abba      5   4                   NaN               0
# 4     abba      5   5                   NaN               0
# 5     abba      5   6                   NaN               0
# 6     abba      5   7                   NaN               0
# 7     abba      5   8                   NaN               0
# 8     abba      5   9                   NaN               0
# 9     abba      5  10                   NaN               0
# 10    abba      5  11                   NaN               0
# 11    abba      5  12                   NaN               0
# 12    abba      5  13                   NaN               0
# 13    abba      5  14                   NaN               0
# 14    abba      5  15                   NaN               0
# 15    abba      5  16                   NaN               0
# 16    abba      5  17                   NaN               0
# 17    abba      5  18                   NaN               0
# 18    abba      5  19                   NaN               0
# 19    abba      5  20                   NaN               0
# 20    abba      5  21                   NaN               0
# 21    abba      5  22                   NaN               0
# 22    abba      5  23                   NaN               0
# 23    abba      5  24                   NaN               0
# 24    abba      5  25                   NaN               0
# 25    abba      5  26                   NaN               0
# 26    abba      5  27                   NaN               0
# 27    abba      5  28                   NaN               0
# 28    abba      5  29                   NaN               0
# 29    abba      5  30                   NaN               0
# ..     ...    ...  ..                   ...             ...
# 210  words      5   1  x|oo|^k|py$|^r|^t|d$              35
# 211  words      5   2  x|oo|^k|py$|^r|^t|d$              35
# 212  words      5   3  x|oo|^k|py$|^r|^t|d$              35
# 213  words      5   4  x|oo|^k|py$|^r|^t|d$              35
# 214  words      5   5  x|oo|^k|py$|^r|^t|d$              35
# 215  words      5   6  x|oo|^k|py$|^r|^t|d$              35
# 216  words      5   7  x|oo|^k|py$|^r|^t|d$              35
# 217  words      5   8  x|oo|^k|py$|^r|^t|d$              35
# 218  words      5   9  x|oo|^k|py$|^r|^t|d$              35
# 219  words      5  10  x|oo|^k|py$|^r|^t|d$              35
# 220  words      5  11  x|oo|^k|py$|^r|^t|d$              35
# 221  words      5  12  x|oo|^k|py$|^r|^t|d$              35
# 222  words      5  13  x|oo|^k|py$|^r|^t|d$              35
# 223  words      5  14  x|oo|^k|py$|^r|^t|d$              35
# 224  words      5  15  x|oo|^k|py$|^r|^t|d$              35
# 225  words      5  16  x|oo|^k|py$|^r|^t|d$              35
# 226  words      5  17  x|oo|^k|py$|^r|^t|d$              35
# 227  words      5  18  x|oo|^k|^t|^r|v|d|h$              35
# 228  words      5  19  x|oo|^k|py$|^r|^t|d$              35
# 229  words      5  20  x|oo|^k|py$|^r|^t|d$              35
# 230  words      5  21  x|oo|^k|py$|^r|^t|d$              35
# 231  words      5  22  x|oo|^k|py$|^r|^t|d$              35
# 232  words      5  23  x|oo|^k|py$|^r|^t|d$              35
# 233  words      5  24  x|oo|^k|py$|^r|^t|d$              35
# 234  words      5  25  x|oo|^k|py$|^r|^t|d$              35
# 235  words      5  26  x|oo|^k|py$|^r|^t|d$              35
# 236  words      5  27  x|oo|^k|py$|^r|^t|d$              35
# 237  words      5  28  x|oo|^k|py$|^r|^t|d$              35
# 238  words      5  29  x|oo|^k|py$|^r|^t|d$              35
# 239  words      5  30  x|oo|^k|py$|^r|^t|d$              35
#
#      Numero_de_comparacoes  Tempo_para_encontrar_melhor_solucao  Tempo_total  \
# 0                        0                                60105        60105
# 1                        0                                60807        60807
# 2                        0                                60953        60953
# 3                        0                                60013        60013
# 4                        0                                61224        61224
# 5                        0                                60510        60510
# 6                        0                                61254        61254
# 7                        0                                60883        60883
# 8                        0                                61405        61405
# 9                        0                                60856        60856
# 10                       0                                60091        60091
# 11                       0                                60100        60100
# 12                       0                                60187        60187
# 13                       0                                61345        61345
# 14                       0                                60754        60754
# 15                       0                                60681        60681
# 16                       0                                61194        61194
# 17                       0                                60794        60794
# 18                       0                                61055        61055
# 19                       0                                60617        60617
# 20                       0                                60840        60840
# 21                       0                                60738        60738
# 22                       0                                61179        61179
# 23                       0                                60666        60666
# 24                       0                                61106        61106
# 25                       0                                60932        60932
# 26                       0                                61262        61262
# 27                       0                                61170        61170
# 28                       0                                61289        61289
# 29                       0                                60563        60563
# ..                     ...                                  ...          ...
# 210                 209199                                11459        35111
# 211                 209199                                11399        34873
# 212                 209199                                11539        35247
# 213                 209199                                11617        37877
# 214                 209199                                13481        46037
# 215                 209199                                14192        45903
# 216                 209199                                15476        47198
# 217                 209199                                13626        44127
# 218                 209199                                12485        38569
# 219                 209199                                11644        38015
# 220                 209199                                12095        37926
# 221                 209199                                12680        42004
# 222                 209199                                15422        45230
# 223                 209199                                18106        55638
# 224                 209199                                16226        51847
# 225                 209199                                20815        55225
# 226                 209199                                15945        46786
# 227                 276771                                27335        60035
# 228                 209199                                21033        60018
# 229                 209199                                17891        56978
# 230                 209199                                19477        60042
# 231                 209199                                15969        43530
# 232                 209199                                12547        42745
# 233                 209199                                14769        39939
# 234                 209199                                11841        37735
# 235                 209199                                14453        41286
# 236                 209199                                15040        42330
# 237                 209199                                12367        37460
# 238                 209199                                13605        43309
# 239                 209199                                13446        42645
#
#      Timed_out
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# 5         True
# 6         True
# 7         True
# 8         True
# 9         True
# 10        True
# 11        True
# 12        True
# 13        True
# 14        True
# 15        True
# 16        True
# 17        True
# 18        True
# 19        True
# 20        True
# 21        True
# 22        True
# 23        True
# 24        True
# 25        True
# 26        True
# 27        True
# 28        True
# 29        True
# ..         ...
# 210      False
# 211      False
# 212      False
# 213      False
# 214      False
# 215      False
# 216      False
# 217      False
# 218      False
# 219      False
# 220      False
# 221      False
# 222      False
# 223      False
# 224      False
# 225      False
# 226      False
# 227       True
# 228       True
# 229      False
# 230       True
# 231      False
# 232      False
# 233      False
# 234      False
# 235      False
# 236      False
# 237      False
# 238      False
# 239      False
#
# [240 rows x 9 columns]
